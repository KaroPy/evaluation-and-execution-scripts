# %%
cd /Users/karolinegriesbach/Documents/Innkeepr/Git/evaluation-and-execution-scripts/

# %%
import logging
import json
import pandas as pd
import awswrangler as wr
from general_functions.return_account_ids import return_account_ids
from general_functions.constants import return_api_url
from general_functions.call_api_with_account_id import send_to_innkeepr_api_paginated

# %%
customer = "Pendix" #6617da9c01c2ab3bd12c63cb
url = return_api_url()
print(f"url = {url}")
account_id = return_account_ids()
account_id = [acc["id"] for acc in account_id if acc["name"] == customer]
account_id = account_id[0]

# %%
with open("/Users/karolinegriesbach/Documents/Innkeepr/Git/evaluation-and-execution-scripts/DataChecks/check_firehose/S3 Bucket 2025-08-04") as json_file:
    data = json.load(json_file)
data
