# %%
cd /Users/karolinegriesbach/Documents/Innkeepr/Git/innkeepr-analytics/

# %%
from src.models.causalml.inference.nn_innkeepr.lstm import NNLSTM

# %% [markdown]
# # Conversion Model

# %%
dir = "/Users/karolinegriesbach/Documents/Innkeepr/Git/innkeepr-analytics/lillydoo-conversion-65840f17a47b22a123981a35/2026-06-22_new_models/"
conversion_model_path = f"{dir}2026-06-22_classifier_NNLSTM_50_nan_nan_nan_saved_model_cv_7_classifier_conversion_probability_model.h5"
conversion_weights= f"{dir}2026-06-22_classifier_NNLSTM_50_nan_nan_nan_saved_model_cv_7_classifier_conversion_probability_model_weights.weights.h5"

# %%
model = NNLSTM({}, conversion_model_path, None)
model = model.load_lstm_model(conversion_model_path, compile=True)
model.load_weights(conversion_weights)
print(model)
print(model.summary())

optimizer = model.optimizer
print("Optimizer:", optimizer.__class__.__name__)
print("Learning rate:", float(optimizer.learning_rate.numpy()))
print("Full optimizer config:", optimizer.get_config())

# %%
timestamp = getattr(model, "timestamp")
timestamp

# %%
model.get_config()

# %%
import h5py, json

with h5py.File(conversion_model_path, "r") as f:
    model_config   = json.loads(f.attrs.get("model_config", "{}"))
    training_config = json.loads(f.attrs.get("training_config", "{}"))

print(json.dumps(model_config, indent=2))
print(json.dumps(training_config, indent=2))

# %% [markdown]
# # Causal Model

# %%
causal_conversion_model_weights = "/Users/karolinegriesbach/Documents/Innkeepr/Git/evaluation-and-execution-scripts/DataChecks/models/model_files/tchibo-aud-68b69fe02e5f2d9a58ce5239/2026-05-03_best_models/2026-01-18_classifier_NNLSTM_50_nan_cv_9_conversion_probability_weights.weights.h5"
causal_conversion_model = "/Users/karolinegriesbach/Documents/Innkeepr/Git/evaluation-and-execution-scripts/DataChecks/models/model_files/tchibo-aud-68b69fe02e5f2d9a58ce5239/2026-05-03_best_models/2026-01-18_classifier_NNLSTM_50_nan_cv_9_conversion_probability.h5"

causal_conv_model = NNLSTM({}, causal_conversion_model, None)
causal_conv_model = causal_conv_model.load_lstm_model(causal_conversion_model, compile=True)
causal_conv_model.load_weights(causal_conversion_model_weights)
print(causal_conv_model)
print(causal_conv_model.summary())

optimizer = causal_conv_model.optimizer
print("Optimizer:", optimizer.__class__.__name__)
print("Learning rate:", float(optimizer.learning_rate.numpy()))
print("Full optimizer config:", optimizer.get_config())

# %%
control_model = "/Users/karolinegriesbach/Documents/Innkeepr/Git/evaluation-and-execution-scripts/DataChecks/models/model_files/tchibo-aud-68b69fe02e5f2d9a58ce5239/2026-05-03_best_models/2026-01-18_classifier_NNLSTM_50_nan_cv_9_group_68b69fe02e5f2d9a58ce5239_control.h5"
control_model_weights = "/Users/karolinegriesbach/Documents/Innkeepr/Git/evaluation-and-execution-scripts/DataChecks/models/model_files/tchibo-aud-68b69fe02e5f2d9a58ce5239/2026-05-03_best_models/2026-01-18_classifier_NNLSTM_50_nan_cv_9_group_68b69fe02e5f2d9a58ce5239_control_weights.weights.h5" 
causal_control_model = NNLSTM({}, control_model, None)
causal_control_model = causal_control_model.load_lstm_model(control_model, compile=True)
causal_control_model.load_weights(control_model_weights)
print(causal_control_model)
print(causal_control_model.summary())

optimizer = causal_control_model.optimizer
print("Optimizer:", optimizer.__class__.__name__)
print("Learning rate:", float(optimizer.learning_rate.numpy()))
print("Full optimizer config:", optimizer.get_config())

# %%
treatment_model = "/Users/karolinegriesbach/Documents/Innkeepr/Git/evaluation-and-execution-scripts/DataChecks/models/model_files/tchibo-aud-68b69fe02e5f2d9a58ce5239/2026-05-03_best_models/2026-01-18_classifier_NNLSTM_50_nan_cv_9_group_68b69fe02e5f2d9a58ce5239_treatment.h5"
treatment_model_weights = "/Users/karolinegriesbach/Documents/Innkeepr/Git/evaluation-and-execution-scripts/DataChecks/models/model_files/tchibo-aud-68b69fe02e5f2d9a58ce5239/2026-05-03_best_models/2026-01-18_classifier_NNLSTM_50_nan_cv_9_group_68b69fe02e5f2d9a58ce5239_treatment_weights.weights.h5"

causal_treatment_model = NNLSTM({}, treatment_model, None)
causal_treatment_model = causal_treatment_model.load_lstm_model(treatment_model, compile=True)
causal_treatment_model.load_weights(treatment_model_weights)
print(causal_treatment_model)
print(causal_treatment_model.summary())

optimizer = causal_treatment_model.optimizer
print("Optimizer:", optimizer.__class__.__name__)
print("Learning rate:", float(optimizer.learning_rate.numpy()))
print("Full optimizer config:", optimizer.get_config())

# %%
causal_propensity_model = "/Users/karolinegriesbach/Documents/Innkeepr/Git/evaluation-and-execution-scripts/DataChecks/models/model_files/tchibo-aud-68b69fe02e5f2d9a58ce5239/2026-05-03_best_models/2026-01-18_classifier_NNLSTM_50_nan_cv_9_group_68b69fe02e5f2d9a58ce5239_propensitymodel.h5"
causal_propensity_model_weights = "/Users/karolinegriesbach/Documents/Innkeepr/Git/evaluation-and-execution-scripts/DataChecks/models/model_files/tchibo-aud-68b69fe02e5f2d9a58ce5239/2026-05-03_best_models/2026-01-18_classifier_NNLSTM_50_nan_cv_9_group_68b69fe02e5f2d9a58ce5239_propensitymodel_weights.weights.h5"


causal_prop_model = NNLSTM({}, causal_propensity_model, None)
causal_prop_model = causal_prop_model.load_lstm_model(causal_propensity_model, compile=True)
causal_prop_model.load_weights(causal_propensity_model_weights)
print(causal_prop_model)
print(causal_prop_model.summary())

optimizer = causal_prop_model.optimizer
print("Optimizer:", optimizer.__class__.__name__)
print("Learning rate:", float(optimizer.learning_rate.numpy()))
print("Full optimizer config:", optimizer.get_config())
