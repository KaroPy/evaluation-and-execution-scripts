# %%
pod_name = "retraining-more-69676c12a5250a665d5555f5-20260121"
text_path = f"/Users/karolinegriesbach/Documents/Innkeepr/Git/Scripts/{pod_name}_metrics.txt"

# %%
list_bytes=[]
with open(text_path, 'r') as f:
    for line in f:
        if pod_name in line:
            try:
                _, _, memory_bytes = line.split()
                memory_bytes = int(memory_bytes.replace('Mi', '').replace(' ', ''))
                list_bytes.append(memory_bytes)
            except:
                continue
list_bytes = list(set(list_bytes))
print(list_bytes)
print(max(list_bytes))
