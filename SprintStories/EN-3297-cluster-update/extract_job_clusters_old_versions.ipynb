# %%
# Die Variable „df“ wurde aus dem URI geladen: /Users/karolinegriesbach/Documents/Innkeepr/Git/evaluation-and-execution-scripts/SprintStories/EN-3297-cluster-update/job_cluster_versions.csv
import pandas as pd
df = pd.read_csv(r'/Users/karolinegriesbach/Documents/Innkeepr/Git/evaluation-and-execution-scripts/SprintStories/EN-3297-cluster-update/job_cluster_versions.csv')

# %%
# filter relevent data
df = df[df["spark_version"]!="15.4.x-scala2.12"]
df = df[df["spark_version"]!="17.3.x-scala2.13"]
df = df.sort_values(by=["job_name","task_key"])
df = df.reset_index(drop=True)
df.to_csv('/Users/karolinegriesbach/Documents/Innkeepr/Git/evaluation-and-execution-scripts/SprintStories/EN-3297-cluster-update/jobs_with_old_cluster.csv')
