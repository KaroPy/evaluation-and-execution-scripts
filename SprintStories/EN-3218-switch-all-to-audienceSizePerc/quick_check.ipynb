# %%
# Die Variable „df“ wurde aus dem URI geladen: /Users/karolinegriesbach/Documents/Innkeepr/Git/evaluation-and-execution-scripts/SprintStories/EN-3218-switch-all-to-audienceSizePerc/missing_audienceSizePerc_20260527.parquet
import pandas as pd
df = pd.read_parquet(r'/Users/karolinegriesbach/Documents/Innkeepr/Git/evaluation-and-execution-scripts/SprintStories/EN-3218-switch-all-to-audienceSizePerc/missing_audienceSizePerc_20260527.parquet')

# %%
df["workspace"].sort_values().unique()

# %%
df[df["workspace"].isin(["Pendix","Vioneers","to teach"])]
