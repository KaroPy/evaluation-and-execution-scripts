# %%
cd /Users/karolinegriesbach/Documents/Innkeepr/Git/consumption-based-costs/
# Out:
# /Users/karolinegriesbach/Documents/Innkeepr/Git/consumption-based-costs
# /Users/karolinegriesbach/.local/share/virtualenvs/consumption-based-costs-wGvc2ut4/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %% [markdown]
# # Script to check costs with known data

# %%
import glob
import pandas as pd

from src.utils.cost_handling import return_cost_per_run

# %%
from_date = "2024-01-01"
to_date="2025-06-23"
timestamp = "2025-06-23 13:23:56.520433"
path_to_remaining_data =  f"/Users/karolinegriesbach/Documents/Innkeepr/Git/consumption-based-costs/data/{from_date}_to_{to_date}/targeting_and_retraining/map_nodes_to_prefect_runs_final_{from_date}_{to_date}.csv"
path_to_targeting_data = f"/Users/karolinegriesbach/Documents/Innkeepr/Git/consumption-based-costs/data/{from_date}_to_{to_date}/costs/final_targeting_costs_{from_date}_{to_date}.csv"
path_to_retraining_data = f"/Users/karolinegriesbach/Documents/Innkeepr/Git/consumption-based-costs/data/{from_date}_to_{to_date}/costs/final_retraining_costs_{from_date}_{to_date}.csv"
path_to_stackit_expected_data = "/Users/karolinegriesbach/Documents/Innkeepr/Git/consumption-based-costs/data/infrastructure_insights/data_for_testing_stackit/"

# %% [markdown]
# # Check StackIT Costs

# %%
discrepancies_allowed = {"General Purpose Server-g1.3-EU01":{}} # due to agentpool discrepancies are allowed

# %%
stackit_files = glob.glob(f"{path_to_stackit_expected_data}/*.csv")
stackit_expected_data = pd.DataFrame()
for file in stackit_files:
 temp = pd.read_csv(file, sep=";")
 date = file.split("/")[-1].split(".")[0].split("_")[-1]
 temp["date"] = date
 temp = temp[[col for col in temp.columns if "Unnamed" not in col]]
 temp["Gesamtkosten"] = temp["Gesamtkosten"].str.replace("€", "").str.replace(" ","").str.replace(",",".").astype(float)
 temp["Gesamtmenge_values"] = temp["Gesamtmenge"].str.replace("Hours", "").str.replace("Gigabyte", "").str.replace(" ","").str.replace(",",".").astype(float)
 stackit_expected_data = pd.concat([stackit_expected_data, temp], axis=0)
stackit_expected_data
# Out:
#                                               Service         SKU  \
# 0          Backup Storage for PostgreSQL Premium-EU01  ST-0040001
# 1   Block Storage for disk volumes Premium-Capacit...  ST-0018001
# 2   Block Storage for disk volumes Premium-Perform...  ST-0010901
# 3   Block Storage for disk volumes Premium-Perform...  ST-0011001
# 4   Block Storage for PostgreSQL Premium-Capacity-...  ST-0069101
# 5   Block Storage for PostgreSQL Premium-Performan...  ST-0068501
# 6                  Compute Optimized Server-c1.2-EU01  ST-0008301
# 7                  Compute Optimized Server-c1.3-EU01  ST-0008901
# 8             Essential-Network-Load-Balancer-10-EU01  ST-0062401
# 9                    General Purpose Server-g1.1-EU01  ST-0008501
# 10                   General Purpose Server-g1.3-EU01  ST-0006901
# 11                   General Purpose Server-g1.4-EU01  ST-0007301
# 12          Kubernetes Engine-Cluster Management-EU01  ST-0010701
# 13                  Memory Optimized Server-b1.3-EU01  ST-0020501
# 14                  Memory Optimized Server-b1.4-EU01  ST-0020701
# 15               Memory Optimized Server-b1a.16d-EU01  ST-0031001
# 16                  Memory Optimized Server-m1.3-EU01  ST-0009301
# 17           Observability-Metrics-Endpoint-100k-EU01  ST-0101401
# 18                    PostgreSQL-Flex-2.4-Single-EU01  ST-0025701
# 19                      Public IP Address (IPv4)-EU01  ST-0070001
# 20                              Tiny Server-t1.2-EU01  ST-0009101
# 0   Block Storage for disk volumes Premium-Capacit...  ST-0018001
# 1   Block Storage for disk volumes Premium-Perform...  ST-0010901
# 2   Block Storage for disk volumes Premium-Perform...  ST-0011001
# 3                  Compute Optimized Server-c1.2-EU01  ST-0008301
# 4                  Compute Optimized Server-c1.3-EU01  ST-0008901
# 5             Essential-Network-Load-Balancer-10-EU01  ST-0062401
# 6                    General Purpose Server-g1.1-EU01  ST-0008501
# 7                    General Purpose Server-g1.3-EU01  ST-0006901
# 8                    General Purpose Server-g1.4-EU01  ST-0007301
# 9           Kubernetes Engine-Cluster Management-EU01  ST-0010701
# 10                  Memory Optimized Server-b1.3-EU01  ST-0020501
# 11                  Memory Optimized Server-b1.4-EU01  ST-0020701
# 12                  Memory Optimized Server-m1.3-EU01  ST-0009301
# 13           Observability-Metrics-Endpoint-100k-EU01  ST-0101401
# 14                      Public IP Address (IPv4)-EU01  ST-0070001
# 15                              Tiny Server-t1.2-EU01  ST-0009101
# 0                   Memory Optimized Server-b1.4-EU01  ST-0020701
# 1                    General Purpose Server-g1.3-EU01  ST-0006901
# 2                   Memory Optimized Server-m1.3-EU01  ST-0009301
# 3                    General Purpose Server-g1.4-EU01  ST-0007301
# 4                   Memory Optimized Server-b1.3-EU01  ST-0020501
# 5                  Compute Optimized Server-c1.3-EU01  ST-0008901
# 6   Block Storage for disk volumes Premium-Perform...  ST-0011001
# 7                     PostgreSQL-Flex-2.4-Single-EU01  ST-0025701
# 8             Essential-Network-Load-Balancer-10-EU01  ST-0062401
# 9                  Compute Optimized Server-c1.2-EU01  ST-0008301
# 10          Kubernetes Engine-Cluster Management-EU01  ST-0010701
# 11                              Tiny Server-t1.2-EU01  ST-0009101
# 12                   General Purpose Server-g1.1-EU01  ST-0008501
# 13  Block Storage for disk volumes Premium-Capacit...  ST-0018001
# 14                      Public IP Address (IPv4)-EU01  ST-0070001
# 15  Block Storage for disk volumes Premium-Perform...  ST-0010901
# 16  Block Storage for PostgreSQL Premium-Performan...  ST-0068501
# 17  Block Storage for PostgreSQL Premium-Capacity-...  ST-0069101
# 18         Backup Storage for PostgreSQL Premium-EU01  ST-0040001
# 19           Observability-Metrics-Endpoint-100k-EU01  ST-0101401
#
#               Gesamtmenge  Gesamtkosten      date  Gesamtmenge_values
# 0        1 Gigabyte Hours          0.00  20250501               1.000
# 1   11.138 Gigabyte Hours          1.01  20250501              11.138
# 2                72 Hours          0.73  20250501              72.000
# 3               230 Hours          4.63  20250501             230.000
# 4    1.200 Gigabyte Hours          0.11  20250501               1.200
# 5                24 Hours          0.48  20250501              24.000
# 6                25 Hours          1.52  20250501              25.000
# 7                37 Hours          5.10  20250501              37.000
# 8               161 Hours          2.10  20250501             161.000
# 9                48 Hours          1.82  20250501              48.000
# 10               77 Hours         11.68  20250501              77.000
# 11               24 Hours          7.28  20250501              24.000
# 12               24 Hours          2.39  20250501              24.000
# 13               16 Hours          6.46  20250501              16.000
# 14               20 Hours         16.15  20250501              20.000
# 15               16 Hours         33.50  20250501              16.000
# 16               38 Hours          7.31  20250501              38.000
# 17               24 Hours          0.00  20250501              24.000
# 18               24 Hours          3.02  20250501              24.000
# 19              171 Hours          0.69  20250501             171.000
# 20              294 Hours          1.60  20250501             294.000
# 0    9.088 Gigabyte Hours          0.82  20250402               9.088
# 1                72 Hours          0.73  20250402              72.000
# 2               160 Hours          3.22  20250402             160.000
# 3                11 Hours          0.67  20250402              11.000
# 4                32 Hours          4.41  20250402              32.000
# 5               139 Hours          1.81  20250402             139.000
# 6                48 Hours          1.82  20250402              48.000
# 7                63 Hours          9.55  20250402              63.000
# 8                24 Hours          7.28  20250402              24.000
# 9                24 Hours          2.39  20250402              24.000
# 10               18 Hours          7.27  20250402              18.000
# 11                7 Hours          5.65  20250402               7.000
# 12               26 Hours          5.00  20250402              26.000
# 13               24 Hours          0.00  20250402              24.000
# 14              161 Hours          0.65  20250402             161.000
# 15              274 Hours          1.49  20250402             274.000
# 0                18 Hours         14.54  20250601              18.000
# 1                94 Hours         14.25  20250601              94.000
# 2                38 Hours          7.31  20250601              38.000
# 3                24 Hours          7.28  20250601              24.000
# 4                16 Hours          6.46  20250601              16.000
# 5                37 Hours          5.10  20250601              37.000
# 6               243 Hours          4.89  20250601             243.000
# 7                24 Hours          3.02  20250601              24.000
# 8               193 Hours          2.52  20250601             193.000
# 9                40 Hours          2.43  20250601              40.000
# 10               24 Hours          2.39  20250601              24.000
# 11              355 Hours          1.93  20250601             355.000
# 12               48 Hours          1.82  20250601              48.000
# 13  11.498 Gigabyte Hours          1.04  20250601              11.498
# 14              202 Hours          0.82  20250601             202.000
# 15               72 Hours          0.73  20250601              72.000
# 16               24 Hours          0.48  20250601              24.000
# 17   1.200 Gigabyte Hours          0.11  20250601               1.200
# 18   1.777 Gigabyte Hours          0.07  20250601               1.777
# 19               24 Hours          0.00  20250601              24.000

# %%
df_targeting = pd.read_csv(path_to_targeting_data)
df_retraining = pd.read_csv(path_to_retraining_data)

# %%
# load remaining data and remove targeting and retraining runs
df_remaining = pd.read_csv(path_to_remaining_data)
df_remaining = df_remaining[df_remaining["Prefect_Deployments"].isin(df_targeting["Prefect_Deployments"].unique().tolist())==False]
df_remaining = df_remaining[df_remaining["Prefect_Deployments"].isin(df_retraining["Prefect_Deployments"].unique().tolist())==False]
df_remaining = return_cost_per_run(df_remaining)
df_remaining["Prefect_Deployments"].value_counts(dropna=False)
# Out:
# Prefect_Deployments
# etlFlow                        1944
# genPropConversionTable         1742
# stackit_default_servers         140
# TEST-googleConversionUpdate       3
# Name: count, dtype: int64

# %%
# combine to stackit data
df_stackit = pd.concat([df_targeting,df_retraining,df_remaining])
df_stackit
# Out:
#             date    cloud      Prefect_Deployments  \
# 0     2025-02-10  stackit                targeting
# 1     2025-02-10  stackit                targeting
# 2     2025-02-10  stackit                targeting
# 3     2025-02-10  stackit                targeting
# 4     2025-02-10  stackit                targeting
# ...          ...      ...                      ...
# 5025  2025-06-18  stackit  stackit_default_servers
# 5026  2025-06-19  stackit  stackit_default_servers
# 5027  2025-06-20  stackit  stackit_default_servers
# 5028  2025-06-21  stackit  stackit_default_servers
# 5029  2025-06-22  stackit  stackit_default_servers
#
#                              serviceName    tenant                  audience  \
# 0     Compute Optimized Server-c1.3-EU01    ective  654199d5c55281d53441fdf2
# 1     Compute Optimized Server-c1.3-EU01    ective  6577083242f53bead377ecc7
# 2     Compute Optimized Server-c1.3-EU01    ective                       NaN
# 3     Compute Optimized Server-c1.3-EU01    pendix  65dde29ef4f24f03238ac989
# 4     Compute Optimized Server-c1.3-EU01  vioneers  6392fae63ceef43bf3448b98
# ...                                  ...       ...                       ...
# 5025  Compute Optimized Server-c1.2-EU01   toteach                       NaN
# 5026  Compute Optimized Server-c1.2-EU01   toteach                       NaN
# 5027  Compute Optimized Server-c1.2-EU01   toteach                       NaN
# 5028  Compute Optimized Server-c1.2-EU01   toteach                       NaN
# 5029  Compute Optimized Server-c1.2-EU01   toteach                       NaN
#
#           duration  sum_duration_serviceName  total_charge_of_serviceName  \
# 0       361.781920              18877.987376                     4.550782
# 1       362.026280              18877.987376                     4.550782
# 2       363.056150              18877.987376                     4.550782
# 3       121.798780              18877.987376                     4.550782
# 4        61.574318              18877.987376                     4.550782
# ...            ...                       ...                          ...
# 5025   7420.993700              13888.465700                     2.608300
# 5026  22896.273000              44704.757000                     3.093565
# 5027  23409.375000              28209.969700                     1.395137
# 5028   7654.261700              14352.137700                     1.334479
# 5029   7550.564500              14260.004000                     3.396855
#
#       part_of_costs_per_run  ...  targetingOutlookDays_nm node_count_nm  \
# 0                  0.019164  ...                      NaN           NaN
# 1                  0.019177  ...                      NaN           NaN
# 2                  0.019232  ...                      NaN           NaN
# 3                  0.006452  ...                      NaN           NaN
# 4                  0.003262  ...                      NaN           NaN
# ...                     ...  ...                      ...           ...
# 5025               0.534328  ...                    720.0           NaN
# 5026               0.512166  ...                    720.0           NaN
# 5027               0.829826  ...                    720.0           NaN
# 5028               0.533319  ...                    720.0           NaN
# 5029               0.529492  ...                    720.0           NaN
#
#       merged_node_name node_type_github cpu_github  memory_github  \
# 0                  NaN              NaN        NaN            NaN
# 1                  NaN              NaN        NaN            NaN
# 2                  NaN              NaN        NaN            NaN
# 3                  NaN              NaN        NaN            NaN
# 4                  NaN              NaN        NaN            NaN
# ...                ...              ...        ...            ...
# 5025  postgres-prefect              NaN        NaN            NaN
# 5026  postgres-prefect              NaN        NaN            NaN
# 5027  postgres-prefect              NaN        NaN            NaN
# 5028  postgres-prefect              NaN        NaN            NaN
# 5029  postgres-prefect              NaN        NaN            NaN
#
#      node_pool_name_github   node_name_costs serviceCategoryName_costs  \
# 0                      NaN               NaN                       NaN
# 1                      NaN               NaN                       NaN
# 2                      NaN               NaN                       NaN
# 3                      NaN               NaN                       NaN
# 4                      NaN               NaN                       NaN
# ...                    ...               ...                       ...
# 5025                   NaN  postgres-prefect            Compute Engine
# 5026                   NaN  postgres-prefect            Compute Engine
# 5027                   NaN  postgres-prefect            Compute Engine
# 5028                   NaN  postgres-prefect            Compute Engine
# 5029                   NaN  postgres-prefect            Compute Engine
#
#      count_service_ocurrences_by_date
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 5025                              2.0
# 5026                              2.0
# 5027                              2.0
# 5028                              2.0
# 5029                              2.0
#
# [11088 rows x 61 columns]

# %%
# compare stackit data to expected data
res = pd.DataFrame(columns=["date","serviceName","expected_costs","data_costs","diff","diff_in_per","orignal_data_costs","expected Service","expected_hours","data_hours"])
for date in stackit_expected_data["date"].unique():
    print(f"Compare data for date {date}")
    temp_stackit_expected = stackit_expected_data[stackit_expected_data["date"]==date]
    temp_stackit = df_stackit[df_stackit["date"]==pd.to_datetime(date).strftime("%Y-%m-%d")]
    temp_stackit["duration"] = temp_stackit["duration"].astype(float)
    temp_stackit_grouped = temp_stackit.groupby(by=["serviceName"])["cost_per_run"].sum().reset_index()
    temp_stackit_grouped["cost_per_run"] = temp_stackit_grouped["cost_per_run"].round(2)
    temp_stackit_grouped_hours = temp_stackit.groupby(by=["serviceName"])["duration"].sum().reset_index()
    temp_stackit_grouped_hours["data_hours"] = temp_stackit_grouped_hours["duration"]/60/60 # from seconds to hours
    temp_stackit_grouped = pd.merge(temp_stackit_grouped, temp_stackit_grouped_hours, how="left", on="serviceName")
    merge_expected_and_data_costs = pd.merge(temp_stackit_expected[["date","Service","Gesamtkosten","Gesamtmenge_values"]], temp_stackit_grouped, left_on="Service", right_on="serviceName", how="left")
    merge_expected_and_data_costs["orignal_data_costs"] = merge_expected_and_data_costs["cost_per_run"]
    merge_expected_and_data_costs["diff"] = merge_expected_and_data_costs["Gesamtkosten"] - merge_expected_and_data_costs["cost_per_run"]
    merge_expected_and_data_costs["diff_in_per"] = (1-(merge_expected_and_data_costs["cost_per_run"]/merge_expected_and_data_costs["Gesamtkosten"]))*100
    merge_expected_and_data_costs = merge_expected_and_data_costs.rename(
        columns={
            "Service": "expected Service",
            "Gesamtkosten": "expected_costs",
            "cost_per_run": "data_costs",
            "Gesamtmenge_values":"expected_hours"
        }
    )
    for service in discrepancies_allowed.keys():
        if service == "General Purpose Server-g1.3-EU01":
            expected_costs = temp_stackit_expected[temp_stackit_expected["Service"]==service]
            expected_costs["cost_per_hour"] = temp_stackit_expected["Gesamtkosten"]/temp_stackit_expected["Gesamtmenge_values"]
            if len(expected_costs) != 1:
                raise Exception(f"Found more than one cost point for service General Purpose Server-g1.3-EU01")
            cost_per_hour = expected_costs["cost_per_hour"].values[0]
            add_costs = 2 * 24 * float(cost_per_hour)
            merge_expected_and_data_costs.loc[merge_expected_and_data_costs["expected Service"] == service, "data_costs"] += add_costs
        
    res = pd.concat([res, merge_expected_and_data_costs[["date","serviceName","expected_costs","data_costs","diff","diff_in_per","orignal_data_costs","expected Service","expected_hours","data_hours"]]], axis=0)
res
# Out:
# Compare data for date 20250501
# Compare data for date 20250402
# Compare data for date 20250601
# /var/folders/yg/6h14_gl52p7_rhsrqbdjv0br0000gn/T/ipykernel_14489/1939067528.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_stackit["duration"] = temp_stackit["duration"].astype(float)
# /var/folders/yg/6h14_gl52p7_rhsrqbdjv0br0000gn/T/ipykernel_14489/1939067528.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   expected_costs["cost_per_hour"] = temp_stackit_expected["Gesamtkosten"]/temp_stackit_expected["Gesamtmenge_values"]
# /var/folders/yg/6h14_gl52p7_rhsrqbdjv0br0000gn/T/ipykernel_14489/1939067528.py:35: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   res = pd.concat([res, merge_expected_and_data_costs[["date","serviceName","expected_costs","data_costs","diff","diff_in_per","orignal_data_costs","expected Service","expected_hours","data_hours"]]], axis=0)
# /var/folders/yg/6h14_gl52p7_rhsrqbdjv0br0000gn/T/ipykernel_14489/1939067528.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_stackit["duration"] = temp_stackit["duration"].astype(float)
# /var/folders/yg/6h14_gl52p7_rhsrqbdjv0br0000gn/T/ipykernel_14489/1939067528.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   expected_costs["cost_per_hour"] = temp_stackit_expected["Gesamtkosten"]/temp_stackit_expected["Gesamtmenge_values"]
# /var/folders/yg/6h14_gl52p7_rhsrqbdjv0br0000gn/T/ipykernel_14489/1939067528.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_stackit["duration"] = temp_stackit["duration"].astype(float)
# /var/folders/yg/6h14_gl52p7_rhsrqbdjv0br0000gn/T/ipykernel_14489/1939067528.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   expected_costs["cost_per_hour"] = temp_stackit_expected["Gesamtkosten"]/temp_stackit_expected["Gesamtmenge_values"]
#         date                           serviceName  expected_costs  \
# 0   20250501                                   NaN            0.00
# 1   20250501                                   NaN            1.01
# 2   20250501                                   NaN            0.73
# 3   20250501                                   NaN            4.63
# 4   20250501                                   NaN            0.11
# 5   20250501                                   NaN            0.48
# 6   20250501    Compute Optimized Server-c1.2-EU01            1.52
# 7   20250501    Compute Optimized Server-c1.3-EU01            5.10
# 8   20250501                                   NaN            2.10
# 9   20250501                                   NaN            1.82
# 10  20250501      General Purpose Server-g1.3-EU01           11.68
# 11  20250501                                   NaN            7.28
# 12  20250501                                   NaN            2.39
# 13  20250501     Memory Optimized Server-b1.3-EU01            6.46
# 14  20250501     Memory Optimized Server-b1.4-EU01           16.15
# 15  20250501  Memory Optimized Server-b1a.16d-EU01           33.50
# 16  20250501     Memory Optimized Server-m1.3-EU01            7.31
# 17  20250501                                   NaN            0.00
# 18  20250501                                   NaN            3.02
# 19  20250501                                   NaN            0.69
# 20  20250501                                   NaN            1.60
# 0   20250402                                   NaN            0.82
# 1   20250402                                   NaN            0.73
# 2   20250402                                   NaN            3.22
# 3   20250402    Compute Optimized Server-c1.2-EU01            0.67
# 4   20250402    Compute Optimized Server-c1.3-EU01            4.41
# 5   20250402                                   NaN            1.81
# 6   20250402                                   NaN            1.82
# 7   20250402      General Purpose Server-g1.3-EU01            9.55
# 8   20250402                                   NaN            7.28
# 9   20250402                                   NaN            2.39
# 10  20250402     Memory Optimized Server-b1.3-EU01            7.27
# 11  20250402     Memory Optimized Server-b1.4-EU01            5.65
# 12  20250402     Memory Optimized Server-m1.3-EU01            5.00
# 13  20250402                                   NaN            0.00
# 14  20250402                                   NaN            0.65
# 15  20250402                                   NaN            1.49
# 0   20250601     Memory Optimized Server-b1.4-EU01           14.54
# 1   20250601      General Purpose Server-g1.3-EU01           14.25
# 2   20250601     Memory Optimized Server-m1.3-EU01            7.31
# 3   20250601                                   NaN            7.28
# 4   20250601     Memory Optimized Server-b1.3-EU01            6.46
# 5   20250601    Compute Optimized Server-c1.3-EU01            5.10
# 6   20250601                                   NaN            4.89
# 7   20250601                                   NaN            3.02
# 8   20250601                                   NaN            2.52
# 9   20250601    Compute Optimized Server-c1.2-EU01            2.43
# 10  20250601                                   NaN            2.39
# 11  20250601                                   NaN            1.93
# 12  20250601                                   NaN            1.82
# 13  20250601                                   NaN            1.04
# 14  20250601                                   NaN            0.82
# 15  20250601                                   NaN            0.73
# 16  20250601                                   NaN            0.48
# 17  20250601                                   NaN            0.11
# 18  20250601                                   NaN            0.07
# 19  20250601                                   NaN            0.00
#
#     data_costs   diff  diff_in_per  orignal_data_costs  \
# 0          NaN    NaN          NaN                 NaN
# 1          NaN    NaN          NaN                 NaN
# 2          NaN    NaN          NaN                 NaN
# 3          NaN    NaN          NaN                 NaN
# 4          NaN    NaN          NaN                 NaN
# 5          NaN    NaN          NaN                 NaN
# 6     1.520000   0.00     0.000000                1.52
# 7     5.100000   0.00     0.000000                5.10
# 8          NaN    NaN          NaN                 NaN
# 9          NaN    NaN          NaN                 NaN
# 10    8.531039  10.43    89.297945                1.25
# 11         NaN    NaN          NaN                 NaN
# 12         NaN    NaN          NaN                 NaN
# 13    6.460000   0.00     0.000000                6.46
# 14   16.150000   0.00     0.000000               16.15
# 15   33.500000   0.00     0.000000               33.50
# 16    7.310000   0.00     0.000000                7.31
# 17         NaN    NaN          NaN                 NaN
# 18         NaN    NaN          NaN                 NaN
# 19         NaN    NaN          NaN                 NaN
# 20         NaN    NaN          NaN                 NaN
# 0          NaN    NaN          NaN                 NaN
# 1          NaN    NaN          NaN                 NaN
# 2          NaN    NaN          NaN                 NaN
# 3     0.670000   0.00     0.000000                0.67
# 4     4.410000   0.00     0.000000                4.41
# 5          NaN    NaN          NaN                 NaN
# 6          NaN    NaN          NaN                 NaN
# 7     7.856190   8.97    93.926702                0.58
# 8          NaN    NaN          NaN                 NaN
# 9          NaN    NaN          NaN                 NaN
# 10    7.270000   0.00     0.000000                7.27
# 11    5.650000   0.00     0.000000                5.65
# 12    5.000000   0.00     0.000000                5.00
# 13         NaN    NaN          NaN                 NaN
# 14         NaN    NaN          NaN                 NaN
# 15         NaN    NaN          NaN                 NaN
# 0    14.540000   0.00     0.000000               14.54
# 1     9.466596  12.06    84.631579                2.19
# 2     7.310000   0.00     0.000000                7.31
# 3          NaN    NaN          NaN                 NaN
# 4     6.460000   0.00     0.000000                6.46
# 5     5.100000   0.00     0.000000                5.10
# 6          NaN    NaN          NaN                 NaN
# 7          NaN    NaN          NaN                 NaN
# 8          NaN    NaN          NaN                 NaN
# 9     2.430000   0.00     0.000000                2.43
# 10         NaN    NaN          NaN                 NaN
# 11         NaN    NaN          NaN                 NaN
# 12         NaN    NaN          NaN                 NaN
# 13         NaN    NaN          NaN                 NaN
# 14         NaN    NaN          NaN                 NaN
# 15         NaN    NaN          NaN                 NaN
# 16         NaN    NaN          NaN                 NaN
# 17         NaN    NaN          NaN                 NaN
# 18         NaN    NaN          NaN                 NaN
# 19         NaN    NaN          NaN                 NaN
#
#                                      expected Service  expected_hours  \
# 0          Backup Storage for PostgreSQL Premium-EU01           1.000
# 1   Block Storage for disk volumes Premium-Capacit...          11.138
# 2   Block Storage for disk volumes Premium-Perform...          72.000
# 3   Block Storage for disk volumes Premium-Perform...         230.000
# 4   Block Storage for PostgreSQL Premium-Capacity-...           1.200
# 5   Block Storage for PostgreSQL Premium-Performan...          24.000
# 6                  Compute Optimized Server-c1.2-EU01          25.000
# 7                  Compute Optimized Server-c1.3-EU01          37.000
# 8             Essential-Network-Load-Balancer-10-EU01         161.000
# 9                    General Purpose Server-g1.1-EU01          48.000
# 10                   General Purpose Server-g1.3-EU01          77.000
# 11                   General Purpose Server-g1.4-EU01          24.000
# 12          Kubernetes Engine-Cluster Management-EU01          24.000
# 13                  Memory Optimized Server-b1.3-EU01          16.000
# 14                  Memory Optimized Server-b1.4-EU01          20.000
# 15               Memory Optimized Server-b1a.16d-EU01          16.000
# 16                  Memory Optimized Server-m1.3-EU01          38.000
# 17           Observability-Metrics-Endpoint-100k-EU01          24.000
# 18                    PostgreSQL-Flex-2.4-Single-EU01          24.000
# 19                      Public IP Address (IPv4)-EU01         171.000
# 20                              Tiny Server-t1.2-EU01         294.000
# 0   Block Storage for disk volumes Premium-Capacit...           9.088
# 1   Block Storage for disk volumes Premium-Perform...          72.000
# 2   Block Storage for disk volumes Premium-Perform...         160.000
# 3                  Compute Optimized Server-c1.2-EU01          11.000
# 4                  Compute Optimized Server-c1.3-EU01          32.000
# 5             Essential-Network-Load-Balancer-10-EU01         139.000
# 6                    General Purpose Server-g1.1-EU01          48.000
# 7                    General Purpose Server-g1.3-EU01          63.000
# 8                    General Purpose Server-g1.4-EU01          24.000
# 9           Kubernetes Engine-Cluster Management-EU01          24.000
# 10                  Memory Optimized Server-b1.3-EU01          18.000
# 11                  Memory Optimized Server-b1.4-EU01           7.000
# 12                  Memory Optimized Server-m1.3-EU01          26.000
# 13           Observability-Metrics-Endpoint-100k-EU01          24.000
# 14                      Public IP Address (IPv4)-EU01         161.000
# 15                              Tiny Server-t1.2-EU01         274.000
# 0                   Memory Optimized Server-b1.4-EU01          18.000
# 1                    General Purpose Server-g1.3-EU01          94.000
# 2                   Memory Optimized Server-m1.3-EU01          38.000
# 3                    General Purpose Server-g1.4-EU01          24.000
# 4                   Memory Optimized Server-b1.3-EU01          16.000
# 5                  Compute Optimized Server-c1.3-EU01          37.000
# 6   Block Storage for disk volumes Premium-Perform...         243.000
# 7                     PostgreSQL-Flex-2.4-Single-EU01          24.000
# 8             Essential-Network-Load-Balancer-10-EU01         193.000
# 9                  Compute Optimized Server-c1.2-EU01          40.000
# 10          Kubernetes Engine-Cluster Management-EU01          24.000
# 11                              Tiny Server-t1.2-EU01         355.000
# 12                   General Purpose Server-g1.1-EU01          48.000
# 13  Block Storage for disk volumes Premium-Capacit...          11.498
# 14                      Public IP Address (IPv4)-EU01         202.000
# 15  Block Storage for disk volumes Premium-Perform...          72.000
# 16  Block Storage for PostgreSQL Premium-Performan...          24.000
# 17  Block Storage for PostgreSQL Premium-Capacity-...           1.200
# 18         Backup Storage for PostgreSQL Premium-EU01           1.777
# 19           Observability-Metrics-Endpoint-100k-EU01          24.000
#
#     data_hours
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6     0.814145
# 7    12.503237
# 8          NaN
# 9          NaN
# 10    5.768028
# 11         NaN
# 12         NaN
# 13   10.941533
# 14    7.512432
# 15    0.179606
# 16   11.776211
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 0          NaN
# 1          NaN
# 2          NaN
# 3     0.348649
# 4     6.336361
# 5          NaN
# 6          NaN
# 7     3.074352
# 8          NaN
# 9          NaN
# 10    5.891653
# 11    0.401219
# 12    5.522315
# 13         NaN
# 14         NaN
# 15         NaN
# 0     9.413798
# 1     8.715587
# 2    16.775247
# 3          NaN
# 4    10.319592
# 5    14.872305
# 6          NaN
# 7          NaN
# 8          NaN
# 9     8.008192
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN

# %%
res_wrong = res[res["diff_in_per"].abs()>0.01]
#res_wrong = res_wrong[res_wrong["serviceName"].isin(discrepancies_allowed.keys())==False]
if len(res_wrong):
    raise Exception(f"There are significant cost differences: {res_wrong}")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[85], line 4
#       2 #res_wrong = res_wrong[res_wrong["serviceName"].isin(discrepancies_allowed.keys())==False]
#       3 if len(res_wrong):
# ----> 4     raise Exception(f"There are significant cost differences: {res_wrong}")
#
# Exception: There are significant cost differences:         date                       serviceName  expected_costs  data_costs  \
# 10  20250501  General Purpose Server-g1.3-EU01           11.68    8.531039
# 7   20250402  General Purpose Server-g1.3-EU01            9.55    7.856190
# 1   20250601  General Purpose Server-g1.3-EU01           14.25    9.466596
#
#      diff  diff_in_per  orignal_data_costs                  expected Service  \
# 10  10.43    89.297945                1.25  General Purpose Server-g1.3-EU01
# 7    8.97    93.926702                0.58  General Purpose Server-g1.3-EU01
# 1   12.06    84.631579                2.19  General Purpose Server-g1.3-EU01
#
#     expected_hours  data_hours
# 10            77.0    5.768028
# 7             63.0    3.074352
# 1             94.0    8.715587
