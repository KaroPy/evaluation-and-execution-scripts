# %%
import re
logs = "INFO:     10.250.2.81:31469 - 'GET /status/8d00134e-2acd-4471-b45f-7172483bbab4 HTTP/1.1' 200 OK /n 2025-10-13 23:25:31,715 - root - INFO - self.path_to_save = tchibo-aud-68b69f372e5f2d9a58cdd132/2025-09-02_best_models/ /n 2025-10-13 23:25:31,748 - root - INFO - Loaded LSTM Model for = ['tchibo-aud-68b69f372e5f2d9a58cdd132/2025-09-02_best_models/2025-09-02_classifier_NNLSTM_50_nan_nan_nan_saved_model_cv_4_group_68b69f372e5f2d9a58cdd132_propensitymodel.h5'] /nINFO:      10.250.3.38:12190 - 'GET /status/8d00134e-2acd-4471-b45f-7172483bbab4 HTTP/1.1' 200 OK /n INFO:     10.250.0.23:9884 - 'GET /status/8d00134e-2acd-4471-b45f-7172483bbab4 HTTP/1.1' 200 OK /n 10.250.3.201:29193 - 'GET /status/8d00134e-2acd-4471-b45f-7172483bbab4 HTTP/1.1' 200 OK /n INFO:     10.250.2.96:34151 - 'GET /status/8d00134e-2acd-4471-b45f-7172483bbab4 HTTP/1.1' 200 OK /n INFO:     10.250.1.99:23751 - 'GET /status/8d00134e-2acd-4471-b45f-7172483bbab4 HTTP/1.1' 200 OK /n INFO:     10.250.2.81:13641 - 'GET /status/8d00134e-2acd-4471-b45f-7172483bbab4 HTTP/1.1' 200 OK /n INFO:     10.250.2.39:40093 - 'GET /status/8d00134e-2acd-4471-b45f-7172483bbab4 HTTP/1.1' 200 OK /n INFO:     10.250.0.255:41590 - 'GET /status/8d00134e-2acd-4471-b45f-7172483bbab4 HTTP/1.1' 200 OK"

expr = re.compile(r"^.*INFO:.*\n?", re.MULTILINE)
logs_without_http_queries = re.sub(expr, "", logs)
logs_without_http_queries

# %%
from kubernetes import client, config as k8_config
from src.utils.stackit_utils import stackit_k8s_login

kube_config_path = stackit_k8s_login()
local_config = client.Configuration()
k8_config.load_kube_config(
            config_file=kube_config_path, client_configuration=local_config
        )
kube_api = client.CoreV1Api(
            api_client=client.ApiClient(configuration=local_config)
)

# %%
api_instance=
api_instance.read_namespaced_pod_log(
        name=pod_name,
        namespace="default",
        since_seconds=since_seconds,
        timestamps=include_timestamps,
    )
